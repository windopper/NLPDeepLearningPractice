# %% [markdown]
# <a href="https://colab.research.google.com/github/windopper/NerualNetworkPracticeInJupyter/blob/main/visualizetrainhistory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# validation_split 은 0~1 값
# 0.25는 훈련데이터의 25%를 검증에 사용한다는 뜻

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train, y_train = x_train/255.0, y_train/255.0

model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')                               
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy']
              )

history = model.fit(x_train, y_train, validation_split=0.25, epochs=10, verbose=1)
print(history.history)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# ...
# 11501568/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.0028 - accuracy: 0.0983 - val_loss: 7.4594e-07 - val_accuracy: 0.0997
# Epoch 2/10
# 1407/1407 [==============================] - 9s 6ms/step - loss: 3.8203e-07 - accuracy: 0.0984 - val_loss: 2.0852e-07 - val_accuracy: 0.0997
# Epoch 3/10
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.1215e-07 - accuracy: 0.0984 - val_loss: 8.6768e-08 - val_accuracy: 0.0997
# Epoch 4/10
# 1407/1407 [==============================] - 8s 6ms/step - loss: 4.3828e-08 - accuracy: 0.0984 - val_loss: 4.3167e-08 - val_accuracy: 0.0997
# Epoch 5/10
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.9267e-08 - accuracy: 0.0984 - val_loss: 2.3237e-08 - val_accuracy: 0.0997
# Epoch 6/10
# 1407/1407 [==============================] - 8s 6ms/step - loss: 9.0943e-09 - accuracy: 0.0984 - val_loss: 1.3351e-08 - val_accuracy: 0.0997
# ...
